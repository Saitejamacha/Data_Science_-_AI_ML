# %% [markdown]
# <a href="https://colab.research.google.com/github/Saitejamacha/Data_Science_-_AI_ML/blob/main/Image_Pixelation_20_09_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
from PIL import Image

# %%
image_path = r"/content/sample_data/IMG_20200527_210104.jpg"

# %%
img = Image.open(image_path)

# %%
# Display resized copy (does not change original)
preview = img.resize((300, 400))  # exact width, height
preview.show()

# %%
preview
# Out:
# <PIL.Image.Image image mode=RGB size=300x400>

# %%
img = img.convert('RGB')

# %%
img_gray = img.convert('L')

# %%
gray_img_preview = img_gray.resize((300, 400))

# %%
gray_img_preview
# Out:
# <PIL.Image.Image image mode=L size=300x400>

# %%
width, height = img_gray.size

# %%
print(width)
print(height)
# Out:
# 1571
# 3408

# %%
img_gray_resize = img_gray.resize((28, 28))

# %%
img_gray_resize
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %%
width1, height1 = img_gray_resize.size

# %%
print(width1)
print(height1)
# Out:
# 28
# 28

# %%
img_gray_resized_array = np.array(img_gray_resize)

# %%
img_gray_resized_array
# Out:
# array([[204, 204, 205, 205, 205, 205, 205, 204, 204, 205, 204, 204, 203,
#         203, 201, 201, 200, 200, 199, 199, 199, 198, 197, 198, 198, 198,
#         198, 199],
#        [204, 204, 205, 205, 205, 205, 205, 205, 205, 205, 205, 206, 206,
#         205, 203, 202, 201, 200, 199, 198, 198, 197, 196, 196, 196, 197,
#         198, 198],
#        [204, 204, 205, 205, 205, 207, 211, 212, 211, 207, 204, 193, 183,
#         186, 197, 201, 205, 204, 201, 197, 197, 196, 196, 196, 197, 197,
#         198, 199],
#        [204, 204, 205, 208, 209, 196, 148, 116, 110,  86,  85,  60,  46,
#          49,  59,  73, 104, 141, 180, 202, 199, 197, 196, 196, 198, 198,
#         199, 199],
#        [204, 204, 207, 187, 102,  54,  28,  30,  25,  27,  27,  31,  24,
#          27,  26,  25,  27,  30,  53, 130, 175, 196, 197, 198, 199, 199,
#         199, 199],
#        [203, 205, 195,  68,  19,  24,  28,  19,   8,  14,  16,  11,  18,
# ...

# %%
plt.figure(figsize = (10, 10))
plt.imshow(img_gray_resized_array, cmap="gray")
plt.colorbar()
plt.show()
