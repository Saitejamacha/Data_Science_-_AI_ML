# %% [markdown]
# <a href="https://colab.research.google.com/github/Saitejamacha/Data_Science_-_AI_ML/blob/main/Wind_Energy_Efficiency_ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/train (1) (4).csv')

# %%
df
# Out:
#                   timestamp  active_power_calculated_by_converter  \
# 0       2021-02-19 20:18:00                            816.636759
# 1       2021-04-27 04:55:00                            419.107829
# 2       2021-01-25 06:26:00                           1303.530558
# 3       2021-10-30 03:47:00                             61.494872
# 4       2021-03-15 00:39:00                            593.514364
# ...                     ...                                   ...
# 909599  2021-04-25 19:12:00                            929.101908
# 909600  2021-02-20 17:37:00                            100.730526
# 909601  2021-10-22 14:18:00                           1120.915965
# 909602  2021-02-08 22:03:00                            123.444564
# 909603  2021-04-09 14:28:00                              4.843147
#
#         active_power_raw  ambient_temperature  generator_speed  \
# 0             834.917206            31.694380      1159.616602
# ...

# %% [markdown]
# # Active power calculuated by converter - The final power the turbine sends to the power grid . This is the useful power after the machine adjustements
#
#
# # Active_power_raw - The raw power directly from the turbine before adjustments
#
# #Ambienr temperature - The outside temperature around the turbine
#
# # generator_speed - how fast the turbine generator is spinning
#
# # generator_winding_temp_max - The hottest temperature inisde the generator coil
#
# # grid power 10 min average - The average power sent to the grid every 10 mins
#
# # nc1_inside_temp - The temperature inside the control box
#
# # nacelle temp - The temperature inside the nacelle to monitor overall machine health
#
#
# # reactive power cacluated by convertor - The extra power that doesn't do useful work but it is needed to keep the electricity system stable
#
#
# # reactive power - The raw measurement of the extra power
#
# # wind_direction_raw - from which direction the wind is blowing (0 - 360)
#
# # wind_speed_raw - The speed of the wind
#
# # wind_speed_turbulence - how much the wind is fluctuation/jitterining

# %%
df.isna().sum()
# Out:
# timestamp                                 0
# active_power_calculated_by_converter      0
# active_power_raw                          0
# ambient_temperature                       0
# generator_speed                           0
# generator_winding_temp_max                0
# grid_power10min_average                   0
# nc1_inside_temp                           0
# nacelle_temp                              0
# reactice_power_calculated_by_converter    0
# reactive_power                            0
# wind_direction_raw                        0
# wind_speed_raw                            0
# wind_speed_turbulence                     0
# turbine_id                                0
# Target                                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909604 entries, 0 to 909603
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   timestamp                               909604 non-null  object
#  1   active_power_calculated_by_converter    909604 non-null  float64
#  2   active_power_raw                        909604 non-null  float64
#  3   ambient_temperature                     909604 non-null  float64
#  4   generator_speed                         909604 non-null  float64
#  5   generator_winding_temp_max              909604 non-null  float64
#  6   grid_power10min_average                 909604 non-null  float64
#  7   nc1_inside_temp                         909604 non-null  float64
#  8   nacelle_temp                            909604 non-null  float64
#  9   reactice_power_calculated_by_converter  909604 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909604 entries, 0 to 909603
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   timestamp                               909604 non-null  datetime64[ns]
#  1   active_power_calculated_by_converter    909604 non-null  float64
#  2   active_power_raw                        909604 non-null  float64
#  3   ambient_temperature                     909604 non-null  float64
#  4   generator_speed                         909604 non-null  float64
#  5   generator_winding_temp_max              909604 non-null  float64
#  6   grid_power10min_average                 909604 non-null  float64
#  7   nc1_inside_temp                         909604 non-null  float64
#  8   nacelle_temp                            909604 non-null  float64
#  9   reactice_power_calculated_by_converter  909604 non-null  float64
# ...

# %%
df
# Out:
#                  timestamp  active_power_calculated_by_converter  \
# 0      2021-02-19 20:18:00                            816.636759
# 1      2021-04-27 04:55:00                            419.107829
# 2      2021-01-25 06:26:00                           1303.530558
# 3      2021-10-30 03:47:00                             61.494872
# 4      2021-03-15 00:39:00                            593.514364
# ...                    ...                                   ...
# 909599 2021-04-25 19:12:00                            929.101908
# 909600 2021-02-20 17:37:00                            100.730526
# 909601 2021-10-22 14:18:00                           1120.915965
# 909602 2021-02-08 22:03:00                            123.444564
# 909603 2021-04-09 14:28:00                              4.843147
#
#         active_power_raw  ambient_temperature  generator_speed  \
# 0             834.917206            31.694380      1159.616602
# ...

# %% [markdown]
# # How does Active Power Calculated by Converter vary with Wind Speed Raw?

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data = df , x = 'wind_speed_raw', y = 'active_power_calculated_by_converter', alpha = 1)
plt.title('How does Active Power Calculated by Converter vary with Wind Speed Raw?')
plt.show()

# %%
# sns.regplot(data = df , x = 'wind_speed_raw', y = 'active_power_calculated_by_converter', scatter = False , color = 'red')
# plt.title('How does Active Power Calculated by Converter vary with Wind Speed Raw?')
# plt.show()

# %%
corr_matrix=df[['active_power_calculated_by_converter','wind_speed_raw']].corr()
sns.heatmap(corr_matrix,annot=True)
plt.title("Correlation matrix")
plt.show()

# %% [markdown]
# # Question: What is the difference between Active Power Raw and Active Power Calculated by Converter?
#
# # loss plot it with respect to time

# %%
df['power_loss'] = df['active_power_raw'] - df['active_power_calculated_by_converter']

# %%
df['power_loss']
# Out:
# 0         18.280446
# 1          1.943044
# 2         34.035583
# 3         -8.013865
# 4         18.144745
#             ...
# 909599    19.339996
# 909600   -12.035927
# 909601    44.100942
# 909602    -7.377645
# 909603     5.936586
# Name: power_loss, Length: 909604, dtype: float64

# %%
# plt.figure(figsize = (10,6))
# sns.lineplot(data = df , x = 'timestamp', y = 'power_loss')
# plt.title('loss plot it with respect to time ')
# plt.show()

# %%
# 12

# %%
df_sorted = df.sort_values(by='timestamp')

# %%
df_sorted
# Out:
#                  timestamp  active_power_calculated_by_converter  \
# 45421  2021-01-01 00:01:00                            828.392253
# 658721 2021-01-01 00:02:00                            734.902262
# 545675 2021-01-01 00:03:00                            748.204336
# 772206 2021-01-01 00:04:00                           1115.585986
# 171257 2021-01-01 00:07:00                            533.733658
# ...                    ...                                   ...
# 668082 2021-12-31 23:58:00                            858.007161
# 83942  2021-12-31 23:58:00                            951.135590
# 214355 2021-12-31 23:58:00                            908.267832
# 554025 2021-12-31 23:58:00                            635.630473
# 545409 2021-12-31 23:59:00                            804.811194
#
#         active_power_raw  ambient_temperature  generator_speed  \
# 45421         847.524780            23.749945      1164.353088
# ...

# %%
plt.figure(figsize = (12,6))
plt.plot(df_sorted['timestamp'], df_sorted['active_power_calculated_by_converter'],color = 'blue')
plt.show()

# %%
# df.set_index('timestamp', inplace=True)
# # Resample hourly and take the mean power loss
# df_resampled = df['power_loss'].resample('1H').mean().reset_index()
# plt.figure(figsize=(14, 6))
# sns.lineplot(data=df_resampled, x='timestamp', y='power_loss', color='crimson')
# plt.axhline(0, color='gray', linestyle='--')
# plt.title('Power Loss (Raw - Calculated) Over Time (Hourly Avg)')
# plt.xlabel('Time')
# plt.ylabel('Power Loss (kW)')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# df_resampled = df['power_loss'].resample('1H').mean().reset_index()
# df_resampled

# %%
df['power_loss']
# Out:
# 0         18.280446
# 1          1.943044
# 2         34.035583
# 3         -8.013865
# 4         18.144745
#             ...
# 909599    19.339996
# 909600   -12.035927
# 909601    44.100942
# 909602    -7.377645
# 909603     5.936586
# Name: power_loss, Length: 909604, dtype: float64

# %%
df
# Out:
#                  timestamp  active_power_calculated_by_converter  \
# 0      2021-02-19 20:18:00                            816.636759
# 1      2021-04-27 04:55:00                            419.107829
# 2      2021-01-25 06:26:00                           1303.530558
# 3      2021-10-30 03:47:00                             61.494872
# 4      2021-03-15 00:39:00                            593.514364
# ...                    ...                                   ...
# 909599 2021-04-25 19:12:00                            929.101908
# 909600 2021-02-20 17:37:00                            100.730526
# 909601 2021-10-22 14:18:00                           1120.915965
# 909602 2021-02-08 22:03:00                            123.444564
# 909603 2021-04-09 14:28:00                              4.843147
#
#         active_power_raw  ambient_temperature  generator_speed  \
# 0             834.917206            31.694380      1159.616602
# ...

# %%
# label transform


from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df['turbine_id'] = le.fit_transform(df['turbine_id'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909604 entries, 0 to 909603
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   timestamp                               909604 non-null  datetime64[ns]
#  1   active_power_calculated_by_converter    909604 non-null  float64
#  2   active_power_raw                        909604 non-null  float64
#  3   ambient_temperature                     909604 non-null  float64
#  4   generator_speed                         909604 non-null  float64
#  5   generator_winding_temp_max              909604 non-null  float64
#  6   grid_power10min_average                 909604 non-null  float64
#  7   nc1_inside_temp                         909604 non-null  float64
#  8   nacelle_temp                            909604 non-null  float64
#  9   reactice_power_calculated_by_converter  909604 non-null  float64
# ...

# %%
# Standardization


X = df.drop(['Target','timestamp'],axis = 1)  # independent
y = df['Target'] # feature

# %%
X
# Out:
#         active_power_calculated_by_converter  active_power_raw  \
# 0                                 816.636759        834.917206
# 1                                 419.107829        421.050873
# 2                                1303.530558       1337.566142
# 3                                  61.494872         53.481008
# 4                                 593.514364        611.659108
# ...                                      ...               ...
# 909599                            929.101908        948.441905
# 909600                            100.730526         88.694599
# 909601                           1120.915965       1165.016907
# 909602                            123.444564        116.066919
# 909603                              4.843147         10.779734
#
#         ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0                 31.694380      1159.616602                   65.954214
# ...

# %%
# Standardize

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X
# Out:
# array([[ 0.61259769,  0.61625423,  0.76261266, ..., -0.33962021,
#         -0.77103581,  0.15863279],
#        [-0.22497659, -0.24168717, -1.57980742, ..., -0.57599023,
#          0.97112267, -0.23843048],
#        [ 1.63845944,  1.65824121, -1.11212664, ..., -0.09321682,
#         -0.98880562,  0.54154472],
#        ...,
#        [ 1.2536993 ,  1.30054811,  0.66377317, ...,  0.94271824,
#          0.53558305,  0.7861726 ],
#        [-0.84792482, -0.87391632,  0.88765591, ..., -1.27421845,
#          1.6244321 , -0.46495995],
#        [-1.09781228, -1.09217576, -0.76273021, ...,  0.97984562,
#         -0.98880562, -0.14137166]])

# %%
# PCA

from sklearn.decomposition import PCA

p = PCA(n_components = 0.95)
pca_data = p.fit_transform(X)

# %%
pca_data.shape
# Out:
# (909604, 9)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(pca_data, y , test_size = 0.3,random_state = 42)

# %%
# linear regression


from sklearn.linear_model import LinearRegression
model = LinearRegression()

# fitting the model

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([46.14034215, 46.86718675, 45.07633691, ..., 45.95154904,
#        45.63127636, 44.94105261])

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test,predictions)

# %%
r2
# Out:
# 0.4163948452706201

# %%
# Decision Tree

from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()

# fitting the model

dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predictions_dt = dt.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2_dt = r2_score(y_test,predictions_dt)

# %%
r2_dt
# Out:
# 0.45375014043853035

# %%
# Random Forest Regressor HW
